# %%
from human_lens import resolve_with_human_lens

# %%
data = {
    'details': 'test', # Task details
    'image': 'abc.png', # Path to image
    'options': ['test1', 'test2', 'test3'] ## List of options
}

# %%
api_key = 'd9d152b1-08d6-4952-a93a-360b04d4eb16' # Replace with your actual API key

# %%
resolve_with_human_lens(api_key, data)
# Out:
# form data {'details': 'test', 'options': '["test1", "test2", "test3"]'}
# ...
